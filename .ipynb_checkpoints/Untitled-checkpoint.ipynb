# %%
import pandas as pd

# %%
df = pd.read_clipboard(sep = '\\s{3}')
df
# Out:
#                          英文全称\t中文全称
# 0                   0\tAlaska 阿拉斯加州
# 1                 1\tArizona\t亚利桑那州
# 2                 2\tArkansas\t阿肯色州
# 3             3\tCalifornia\t加利福尼亚州
# 4                4\tColorado\t科罗拉多州
# 5             5\tConnecticut\t康涅狄格州
# 6                 6\tDelaware\t特拉华州
# 7                 7\tFlorida\t佛罗里达州
# 8                  8\tGeorgia\t佐治亚州
# 9                   9\tHawaii\t夏威夷州
# 10                  10\tIdaho\t爱达华州
# 11               11\tIllinois\t伊利诺州
# 12               12\tIndiana\t印地安那州
# 13                   13\tIowa\t艾奥瓦州
# 14                 14\tKansas\t堪萨斯州
# 15               15\tKentucky\t肯塔基州
# 16            16\tLouisiana\t路易斯安那州
# 17                   17\tMaine\t缅因州
# 18               18\tMaryland\t马里兰州
# 19         19\tMassachusetts\t麻萨诸塞州
# 20               20\tMichigan\t密歇根州
# 21             21\tMinnesota\t明尼苏达州
# 22           22\tMississippi\t密西西比州
# 23               23\tMissouri\t密苏里州
# 24                24\tMontana\t蒙大拿州
# ...

# %%
import os
df.to_excel('美国五十州中英文.xlsx')
os.startfile('美国五十州中英文.xlsx')

# %%
df['中文全称'] = df['中文全称'].str.strip()
df['中文全称']
# Out:
# 0         阿拉斯加州
# 1         亚利桑那州
# 2          阿肯色州
# 3        加利福尼亚州
# 4         科罗拉多州
# 5         康涅狄格州
# 6          特拉华州
# 7         佛罗里达州
# 8          佐治亚州
# 9          夏威夷州
# 10         爱达华州
# 11         伊利诺州
# 12        印地安那州
# 13         艾奥瓦州
# 14         堪萨斯州
# 15         肯塔基州
# 16       路易斯安那州
# 17          缅因州
# 18         马里兰州
# 19        麻萨诸塞州
# 20         密歇根州
# 21        明尼苏达州
# 22        密西西比州
# 23         密苏里州
# 24         蒙大拿州
# 25       内布拉斯加州
# 26         内华达州
# 27       新罕布什尔州
# 28         新泽西州
# 29        新墨西哥州
# 30          纽约州
# 31       北卡罗来纳州
# 32        北达科他州
# 33         俄亥俄州
# 34       俄克拉何马州
# 35         俄勒冈州
# 36       宾夕法尼亚州
# 37         罗得岛州
# 38       南卡罗来纳州
# 39        南达科他州
# 40         田纳西州
# 41        得克萨斯州
# 42          犹他州
# 43         佛蒙特州
# 44        弗吉尼亚州
# 45         华盛顿州
# 46       西弗吉尼亚州
# 47        威斯康星州
# 48         怀俄明州
# 49    华盛顿哥伦比亚特区
# Name: 中文全称, dtype: object

# %%
df.columns
# Out:
# Index(['英文全称 ', '中文全称'], dtype='object')

# %%
a = [i.strip() for i in df.columns.to_list()]
a
# Out:
# ['英文全称', '中文全称']

# %%
df.columns = a
df.columns
# Out:
# Index(['英文全称', '中文全称'], dtype='object')

# %%
df['英文全称'] = df['英文全称'].str.strip()
df['英文全称']
# Out:
# 0              Alaska
# 1             Arizona
# 2            Arkansas
# 3          California
# 4            Colorado
# 5         Connecticut
# 6            Delaware
# 7             Florida
# 8             Georgia
# 9              Hawaii
# 10              Idaho
# 11           Illinois
# 12            Indiana
# 13               Iowa
# 14             Kansas
# 15           Kentucky
# 16          Louisiana
# 17              Maine
# 18           Maryland
# 19      Massachusetts
# 20           Michigan
# 21          Minnesota
# 22        Mississippi
# 23           Missouri
# 24            Montana
# 25           Nebraska
# 26             Nevada
# 27      New Hampshire
# 28          NewJersey
# 29         New Mexico
# 30            NewYork
# 31     North Carolina
# 32       North Dakota
# 33               Ohio
# 34           Oklahoma
# 35             Oregon
# 36       Pennsylvania
# 37       Rhode Island
# 38     South Carolina
# 39       South Dakota
# 40          Tennessee
# ...

# %%
df
# Out:
#                英文全称       中文全称
# 0            Alaska      阿拉斯加州
# 1           Arizona      亚利桑那州
# 2          Arkansas       阿肯色州
# 3        California     加利福尼亚州
# 4          Colorado      科罗拉多州
# 5       Connecticut      康涅狄格州
# 6          Delaware       特拉华州
# 7           Florida      佛罗里达州
# 8           Georgia       佐治亚州
# 9            Hawaii       夏威夷州
# 10            Idaho       爱达华州
# 11         Illinois       伊利诺州
# 12          Indiana      印地安那州
# 13             Iowa       艾奥瓦州
# 14           Kansas       堪萨斯州
# 15         Kentucky       肯塔基州
# 16        Louisiana     路易斯安那州
# 17            Maine        缅因州
# 18         Maryland       马里兰州
# 19    Massachusetts      麻萨诸塞州
# 20         Michigan       密歇根州
# 21        Minnesota      明尼苏达州
# 22      Mississippi      密西西比州
# 23         Missouri       密苏里州
# 24          Montana       蒙大拿州
# 25         Nebraska     内布拉斯加州
# 26           Nevada       内华达州
# 27    New Hampshire     新罕布什尔州
# 28        NewJersey       新泽西州
# ...

# %%
df.to_excel('美国五十州中英文.xlsx',index = False)
os.startfile('美国五十州中英文.xlsx')
