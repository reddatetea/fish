# %%
import pandas as pd

# %%
def danjuChuli(df):
    df = df.dropna(how='all', axis=0)
    cols = [i for i in df.columns.to_list() if 'Unnamed' not in i]
    df = df[cols]
    # get maxrows
    for label, ser in df.items():
        for num, x in enumerate(ser):
            if isinstance(x, str):
                if '合计' in x:
                    index = num
                    print(index)
                    break
    df = df.iloc[:index]
    df = df.dropna(how='all', axis=1)
    return df

# %%
fname = r"F:\a00nutstore\006\zw\产成品日报表\2024年\8月6日\销售订单明细表8.6未审核订单下午.xlsx"
df = pd.read_excel(fname,skiprows = 7)
df
# Out:
#      Unnamed: 0        单据日期                 创建时间          单据编号     客户编码  \
# 0           NaN  2024-08-06  2024-08-06 16:11:13  SO-2024-0413   010426
# 1           NaN  2024-08-06  2024-08-06 16:10:46  SO-2024-0412   010137
# 2           NaN  2024-08-06  2024-08-06 16:10:22  SO-2024-0411   010101
# 3           NaN  2024-08-06  2024-08-06 16:09:35  SO-2024-0410   010147
# 4           NaN  2024-08-06  2024-08-06 16:09:04  SO-2024-0409   010132
# ..          ...         ...                  ...           ...      ...
# 229         NaN         NaN                  NaN           NaN      NaN
# 230         NaN        制表人:                   黄锦           NaN    打印日期:
# 231         NaN         NaN                  NaN           NaN      NaN
# 232         NaN         NaN                  NaN           NaN      NaN
# 233         NaN         NaN                  NaN           NaN  第1页/共1页
#
#                    客户  部门编码     部门   结算客户编码              结算客户  ...  \
# ...

# %%
df1 = danjuChuli(df)
df1
# Out:
# 228
#            单据日期                 创建时间          单据编号    客户编码                客户  \
# 0    2024-08-06  2024-08-06 16:11:13  SO-2024-0413  010426  武汉市黄陂区启成电子商务商行J3
# 1    2024-08-06  2024-08-06 16:10:46  SO-2024-0412  010137       武汉今日成纸业有限公司
# 2    2024-08-06  2024-08-06 16:10:22  SO-2024-0411  010101    武汉开先文化用品有限责任公司
# 3    2024-08-06  2024-08-06 16:09:35  SO-2024-0410  010147     武汉金宸翰办公用品有限公司
# 4    2024-08-06  2024-08-06 16:09:04  SO-2024-0409  010132       武汉金胜辉商贸有限公司
# ..          ...                  ...           ...     ...               ...
# 223  2024-08-06  2024-08-06 08:59:59  SO-2024-0372  010200        武汉米圣贸易有限公司
# 224  2024-08-06  2024-08-06 08:59:59  SO-2024-0372  010200        武汉米圣贸易有限公司
# 225  2024-08-06  2024-08-06 08:59:59  SO-2024-0372  010200        武汉米圣贸易有限公司
# 226  2024-08-06  2024-08-06 08:59:59  SO-2024-0372  010200        武汉米圣贸易有限公司
# 227  2024-08-06  2024-08-06 08:59:59  SO-2024-0372  010200        武汉米圣贸易有限公司
#
# ...
