# %%
from tkinter import *
win = Tk()
win.title('棋谱录入')
win.geometry('400x600+500+200')

lab1 = Label(win,text='Game',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row=1,column=0,sticky='W')
game = StringVar(value='Chinese Chess')
entry1 = Entry(win,textvariable=game,width = '30',justify='left')
entry1.grid(row=1,column=5)

lab2 = Label(win,text = 'Event',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 2,column=0,sticky='W')
entry2 = Entry(win,width = '30',justify='left')
entry2.grid(row=2,column=5)

lab3 = Label(win,text = 'Round',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 3,column=0,sticky='W')
entry3 = Entry(win,width = '30',justify='left')
entry3.grid(row=3,column=5)

lab4 = Label(win,text = 'Date',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 4,column=0,sticky='W')
date = StringVar(value='2024-1-1 12:57')
entry4 = Entry(win,textvariable=date,width = '30',justify='left')
entry4.grid(row=4,column=5)

lab5 = Label(win,text = 'Site',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 5,column=0,sticky='W')
site = StringVar(value = '天天象棋')
entry5 = Entry(win,textvariable= site,width = '30',justify='left')
entry5.grid(row=5,column=5)

lab6 = Label(win,text = 'Red',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 6,column=0,sticky='W')
red = StringVar(value = 'siwenzhang')
entry6 = Entry(win,textvariable = red,width = '30',justify='left')
entry6.grid(row=6,column=5)

lab7 = Label(win,text = 'RedTeam',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 7,column=0,sticky='W')
redteam = StringVar(value = '楚河')
entry7 = Entry(win,textvariable = redteam,width = '30',justify='left')
entry7.grid(row=7,column=5)

lab8 = Label(win,text = 'Black',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 8,column=0,sticky='W')
black = StringVar(value = 'siwenzhang')
entry8 = Entry(win,textvariable = black,width = '30',justify='left')
entry8.grid(row=8,column=5)

lab9 = Label(win,text = 'BlackTeam',font=14, anchor='w',justify='left').grid(padx = 5,pady=9,row = 9,column=0,sticky='W')
blackteam = StringVar(value = '汉界')
entry9 = Entry(win,textvariable=blackteam,width = '30',justify='left')
entry9.grid(row=9,column=5)

lab10 = Label(win,text = 'Result',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 10,column=0,sticky='W')
result = StringVar(value = '*')
entry10 = Entry(win,textvariable = result,width = '30',justify='left')
entry10.grid(row=10,column=5)

lab11 = Label(win,text = 'ECCO',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 11,column=0,sticky='W')
entry11 = Entry(win,width = '30',justify='left')
entry11.grid(row=11,column=5)

lab12 = Label(win,text = 'FEN',font=14, anchor='w',justify='left').grid(padx = 5,pady=10,row = 12,column=0,sticky='W')
entry12 = Entry(win,width = '30',justify='left')
entry12.grid(row=12,column=5)

def show():
    global txt1
    txt1 = entry1.get()
    txt2 = entry2.get()
    txt3 = entry3.get()
    txt4 = entry4.get()
    txt5 = entry5.get()
    txt6 = entry6.get()
    txt7 = entry7.get()
    txt8 = entry8.get()
    txt9 = entry9.get()
    txt10 = entry10.get()
    txt11 = entry11.get()
    
    print(txt1,txt2,txt3,txt4,txt5,txt6,txt7,txt8,txt9,txt10,txt11)
    
button =Button(win,text='确定',command=show).grid(row=15,column=1)
win.mainloop()
