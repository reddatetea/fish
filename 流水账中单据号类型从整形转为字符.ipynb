# %%
import numpy as np
import pandas as pd
import openpyxl 
import os
import easygui

# %%
fname = r'D:\ribaobiao\水账.xls'
df = pd.read_excel(fname,dtype = {'单据号':str})
df
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#              日期   单据类型         单据号 业务类型  业务号    仓库  收发类别    部门  业务员 供货单位  ...  \
# 0    2023-05-06  材料出库单  0000005356   领料  NaN  原材料库  生产领料  软抄车间  NaN  NaN  ...
# 1    2023-05-06  材料出库单  0000005356   领料  NaN  原材料库  生产领料  软抄车间  NaN  NaN  ...
# 2    2023-05-06  材料出库单  0000005356   领料  NaN  原材料库  生产领料  软抄车间  NaN  NaN  ...
# 3    2023-05-06  材料出库单  0000005357   领料  NaN  原材料库  生产领料  书芯车间  NaN  NaN  ...
# 4    2023-05-06  材料出库单  0000005358   领料  NaN  原材料库  生产领料  软抄车间  NaN  NaN  ...
# ..          ...    ...         ...  ...  ...   ...   ...   ...  ...  ...  ...
# 377  2023-05-04  材料出库单  0000005331   领料  NaN  原材料库  生产领料  柔版车间  NaN  NaN  ...
# 378  2023-05-04  材料出库单  0000005331   领料  NaN  原材料库  生产领料  柔版车间  NaN  NaN  ...
# 379  2023-05-04  材料出库单  0000005331   领料  NaN  原材料库  生产领料  柔版车间  NaN  NaN  ...
# 380  2023-05-04  材料出库单  0000005331   领料  NaN  原材料库  生产领料  柔版车间  NaN  NaN  ...
# ...

# %%
fname = r'F:\a00nutstore\006\zw\原材料实时流水账\原材料实时流水账.xlsx'
df1 = pd.read_excel(fname,sheet_name = '流水账',dtype = {'单据号':str})
df1
# Out:
#               日期       单据号         供货单位                品名  单位     入库数量  \
# 0     2014-03-24  90021129  驻马店白云纸业有限公司  55白云R级双胶787*1092   令    300.0
# 1     2014-03-24  90021129  驻马店白云纸业有限公司       55白云R级卷筒815  公斤  28665.0
# 2     2014-03-24  90021130  驻马店白云纸业有限公司    55白云双胶787*1092   令    180.0
# 3     2014-03-24  90021130  驻马店白云纸业有限公司    72白云双胶787*1092   令    352.0
# 4     2014-03-25  90021131  驻马店白云纸业有限公司  55白云R级双胶787*1092   令   1230.0
# ...          ...       ...          ...               ...  ..      ...
# 47703 2023-05-06  00002023  武汉市安琪包装有限公司           6502空白袋   个   8400.0
# 47704 2023-05-06  00002023  武汉市安琪包装有限公司            25K空白袋   个  30100.0
# 47705 2023-05-06  00002025       湖北佰晟包装         EX-200外贸箱   个   2000.0
# 47706 2023-05-06  00002026      孝感雅都新材料          EXLA580箱   个    523.0
# 47707 2023-05-06  00002027       浙江众成包装          390卷膜POF   卷     80.0
#
#            入库单价       入库金额   cwName priceName       期间       送货日期     白云期间  \
# ...
